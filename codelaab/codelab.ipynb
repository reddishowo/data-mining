# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)
pd.set_option("display.colheader_justify", "center")
pd.set_option("display.precision", 2)

# %%
dataset = "dataset.csv"
df = pd.read_csv(dataset)

# %%
# df['Dues amount'] = df['Dues amount'].replace({r'\$': '', ',': ''}, regex=True).astype(float)

# %%
print(df.head(7))
# Out:
#    Member ID     Last name       First name       Address 1              Address 2       Address 3  Address 4   Address 5 Dues amount Membership valid through     Member type
# 0   100011                 Tsao       Danny           27 Wu Tzu St           Tamshui 251     NaN         Taiwan       NaN     $200            3/25/2021         Professional Member
# 1   100012                  Lei     Colleen     88 6th Avenue Teda        300457 TIANJIN     NaN          China       NaN     $500           10/12/2023            Corporate Member
# 2   100013                 Roth       Nancy       Hoefenstrasse 31            Muehlethal     NaN    Switzerland      4812     $100            1/11/2023           Student Associate
# 3   100014    Meneses Contreras  Karl-Oscar  Poniente 134 Ste. 740          02300 México     DIF         Mexico       NaN     $500            2/26/2021            Corporate Member
# 4   100015                Nunez      Helmut      Andador Pinos 345         45235 Zapopan     JAL         Mexico       NaN     $200            7/29/2023         Professional Member
# 5   100016          Fitzpatrick      Dmitry       22 Hemingford Pl                Whitby      ON         Canada   L1R 1G1     $100           12/15/2007           Student Associate
# 6   100017               Andreu        Leya   Nevada de Colima 104  20280 Aguascalientes     NaN         Mexico       NaN     $200            3/31/2021         Professional Member

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Member ID                 71 non-null     int64
#  1   Last name                 71 non-null     object
#  2   First name                71 non-null     object
#  3   Address 1                 71 non-null     object
#  4   Address 2                 71 non-null     object
#  5   Address 3                 30 non-null     object
#  6   Address 4                 71 non-null     object
#  7   Address 5                 39 non-null     object
#  8   Dues amount               71 non-null     float64
#  9   Membership valid through  71 non-null     object
#  10  Member type               71 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 6.2+ KB
# None

# %%
total_dues = df["Dues amount"].sum()
print(total_dues)
# Out:
# $200$500$100$500$200$100$200$200$500$200$200$100$100$100$200$200$500$200$200$100$100$100$200$200$200$100$200$200$200$200$100$500$200$200$200$200$200$200$200$100$100$200$100$500$500$200$200$1,000$200$200$1,000$200$200$200$200$200$1,000$1,000$200$100$100$100$200$100$200$200$100$100$200$1,000$200

# %%
average_dues = df["Dues amount"].mean()
print(average_dues)
# Out:
# 259.15492957746477
